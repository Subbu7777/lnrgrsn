# %% [markdown]
# # Linear Regression

# %% [markdown]
# Linear Regression is a supervised learning algorithm, which works best for continuous data.
# Linear Regression is most common and one of the powerful algorithm.
# In this lecture, we will talk about this in detail.

# %% [markdown]
# So below, is our scatter data,
# ![scatter.png](attachment:scatter.png)
#
# We will fit the straight line and make predictions.
# ![fitted_line.png](attachment:fitted_line.png)

# %% [markdown]
# So, above we fitted the straight line on our inputs and we are predicting the output using x and y.

# %% [markdown]
# # How do we make this straight line?
#
# For making this straight line we have a function "h(x)" as:-
#
# $\hat{Y} = h(x) =  \Theta_0*x_{0} + \Theta_1*x_{1} + \Theta_2*x_{2} \ + \Theta_3*x_{3} + \Theta_n*x_{n}$

# %% [markdown]
# In the above equation, $\Theta_0$ is a bias term often called the intercept and $\Theta_1 , \Theta_2 \ , \Theta_3 , ... \Theta_n$ are the feature weights.

# %% [markdown]
# Above is the equation of Linear Regression with multiple variables often called **Multivariate Linear Regression**,
# There is also a univariate linear regression, which has only one feature means on the basis of only one feature we have to predict the output but in general you will see **Multivariate Linear Regression** a lot and In above equation we have multiple features and on the basic of multiple features , we are predicting the output.

# %% [markdown]
# More vectorized form of the above equation is
#
# $\hat{Y} = h(x) = \Theta*X$

# %% [markdown]
# $\Theta\$ is the parameter vector containing the bias term and feature weights often abbreviated as a giant vector theta.

# %% [markdown]
# X is the feature vector containing all x's and note $x_0\$ is always equals to 1. theta and x is the dot product which is equals to the same equation above.

# %% [markdown]
# **Example**:- let's say you have one only one feature and basis on that you have to predict, so let's take
# $\Theta_0$ = 2.5 and $\Theta_1 = 3.6$

# %% [markdown]
# if, we make use of this bias term and feature weights,
# $\hat{Y} = h(x) = \Theta_0 + \Theta_1*x_{1}$

# %% [markdown]
# $\hat{Y} = h(x) = 2.5 + 3.6 * x$

# %% [markdown]
# Now, you can put the values of x and then you will get your desired output.

# %% [markdown]
# ## Cost Function J($\Theta$)

# %% [markdown]
# So, we have choose our $\Theta_0$  and $\Theta_1 $ but who gaurantees that our parameters is the best parameter, so for checking the accuracy of our hypothesis or our parameters, we have cost function.

# %% [markdown]
# Cost Function J($\Theta$) is directly propostional to the error. Higher the cost function is higher the error is and vice versa

# %% [markdown]
# There are two algorithms which are mostly used in calculating the cost function,
#
# - MSE ( Mean Squared Error )
# - RMSE ( Root Mean Squared Error )
#
# for now we will make use of MSE, so the equation of Mean Squared Error is:-

# %% [markdown]
# for now we will focus on MSE, so the equation of Mean Squared Error is:-

# %% [markdown]
# MSE($\theta_0,\theta_1,\theta_2,\theta_3,...,\theta_n $) = $\frac{1}{m} +  \sum  \limits _{i = 1} ^{m} (\Theta^{T}x^{i} - y^{i})^{2}$

# %% [markdown]
# Understanding the above equation
#
# - m is the size of training examples, we can take out with the 'len(y)'.

# %% [markdown]
# Below we have a simple data
# ![pltowithl.png](attachment:pltowithl.png)

# %% [markdown]
# Now, we fit a line on this data
# ![newplot.png](attachment:newplot.png)
# Cost function is taking out the distance between actual and predicted values by subtracting $h(x^{i}) - y^{i}$ and at last we are squaring them up.

# %% [markdown]
# So, If our cost function is relatively large then we haven't choose the best theta, we have to try to another theta.

# %% [markdown]
# There is a direct method or we can say equation which is called the normal equation,which gives the best $\Theta$ parmeter. Below is the equation of of Normal equation.

# %% [markdown]
# $\Theta$ = ($X^{T}X)^{-1} X^{T} y$

# %% [markdown]
# ### Implementation of Normal Equation

# %%
import numpy as np
import matplotlib.pyplot as plt
def generate_data():
    X = 2 * np.random.rand(100, 1) #100 rows 1 clmns *2
    y = 4 + 3 * X + np.random.randn(100, 1)  #increasing y value than the x  
    
    return  X,y

def get_best_param(X, y):      
    X_b = np.c_[np.ones((100, 1)), X]  # add x0 = 1 to each instance ,100 rws 1 clmns+ x combine two arrays horizntly
    theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y) # normal equation formula 
    print(X_b,"lkjh",theta_best)
    return theta_best

def predict(X,theta): 
    return X.dot(theta) #multiply of matrix

X,y = generate_data() 
plt.plot(X,y,"r.")

theta = get_best_param(X,y) 
theta

X_to_pred = np.array([[0],[2]]) 
X_new_b = np.c_[np.ones((2, 1)), X_to_pred] 
predict= predict(X_new_b,theta)

plt.plot(X_to_pred, predict)
plt.plot(X,y,"r.") 
plt.show()
# Out:
# [[1.         1.69115319]
#  [1.         1.95017303]
#  [1.         0.8717734 ]
#  [1.         0.38266525]
#  [1.         1.81319466]
#  [1.         0.39371276]
#  [1.         1.03312154]
#  [1.         0.18697691]
#  [1.         0.56035111]
#  [1.         1.76090495]
#  [1.         1.12215585]
#  [1.         1.84102811]
#  [1.         1.05950025]
#  [1.         0.29091089]
#  [1.         0.33447413]
#  [1.         1.46660813]
#  [1.         0.00727102]
#  [1.         0.83613957]
#  [1.         0.8918239 ]
#  [1.         0.58376888]
#  [1.         1.78626652]
#  [1.         1.69986203]
#  [1.         0.10568958]
#  [1.         1.89271846]
#  [1.         1.19731383]
#  [1.         1.02394477]
#  [1.         0.28870268]
#  [1.         0.01040677]
#  [1.         1.91836453]
#  [1.         1.0580879 ]
#  [1.         1.61494839]
#  [1.         0.06358107]
#  [1.         0.43247249]
#  [1.         1.53333319]
#  [1.         0.95371288]
#  [1.         0.19708798]
#  [1.         1.25367938]
# ...

# %% [markdown]
# ## Batch Gradient Descent

# %% [markdown]
# Gradient Descent is an Opitmization algorithm that help us to find the best theta parameter, it simple tweak the parameters to reduce our cost function, so if our cost function reduces it means that we are getting good theta parameters.
#
#
# ![visualization.gif](attachment:visualization.gif)

# %% [markdown]
# Let's take another example
# ![gradient_descent.png](attachment:gradient_descent.png)

# %% [markdown]
# ## Implementation of Gradient Descent

# %% [markdown]
# To Implement gradient descent, you need to compute the gradient of the cost function with respect to each model parameter $\Theta_{j}$

# %% [markdown]
# You need to compute the **partial deriviative** of our cost function i.e how much cost function will change when if you change $\Theta$ little bit.

# %% [markdown]
# $\frac{\partial}{\partial \Theta_{j} }{J}(\Theta) = \frac{2}{m} +  \sum  \limits _{i = 1} ^{m} (\Theta^{T}x^{i} - y^{i})^{2} $

# %% [markdown]
# ### What we are doing?

# %% [markdown]
# $\frac{\partial}{\partial \Theta_{0} }{J}(\Theta) = \frac{2}{m} +  \sum  \limits _{i = 1} ^{m} (\Theta^{T}x^{i} - y^{i})^{2} $

# %% [markdown]
# $\frac{\partial}{\partial \Theta_{1} }{J}(\Theta) = \frac{2}{m} +  \sum  \limits _{i = 1} ^{m} (\Theta^{T}x^{i} - y^{i})^{2} $

# %% [markdown]
# $\frac{\partial}{\partial \Theta_{2} }{J}(\Theta) = \frac{2}{m} +  \sum  \limits _{i = 1} ^{m} (\Theta^{T}x^{i} - y^{i})^{2} $

# %% [markdown]
#             .
#             .
#             .
# $\frac{\partial}{\partial \Theta_{j} }{J}(\Theta) = \frac{2}{m} +  \sum  \limits _{i = 1} ^{m} (\Theta^{T}x^{i} - y^{i})^{2} $

# %% [markdown]
# ### Vectorized Form

# %% [markdown]
# $\bigtriangledown {J}(\Theta) = \frac{2}{m} . X^{T}(X\Theta - y)$

# %% [markdown]
# ### Gradient Descent Step

# %% [markdown]
# ![visualization.gif](attachment:visualization.gif)

# %% [markdown]
# $\Theta_{j} := \Theta_{j} - \alpha \bigtriangledown{J}(\Theta)$

# %% [markdown]
# Here we are taking gradient step to reach to our global minimum, so that's why we are updating our previous theta parameter with the new one.

# %% [markdown]
# ### How to Choose the learning rate?

# %% [markdown]
# You have to tune the learning rate means you have to try different different rates and see your model how it performs.
#
# If you choose **very small learning rate**, it will be very very slow and it will never converge to the local minimum.
#
# If you choose **very large learning rate**, your model might diverge and never converge to the local minimum.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Implementation of Linear Regression From Scratch

# %%
def model(X, Y, learning_rate, iteration):
    m = Y.size
    theta = np.zeros((2, 1))
    cost_list = []
    for i in range(iteration):
        y_pred = np.dot(X, theta)
        cost = (1/(2*m))*np.sum(np.square(y_pred - Y))
        d_theta = (1/m)*np.dot(X.T, y_pred - Y)
        theta = theta - learning_rate*d_theta
        cost_list.append(cost)

    return theta, cost_list

# %% [markdown]
# ### Implementation of Linear Regression With Scikit Learn

# %%
from sklearn.linear_model import LinearRegression 
lin_reg = LinearRegression() # object
lin_reg.fit(X, y) #gradient desent
lin_reg.intercept_, lin_reg.coef_ #bias term,future bias
lin_reg.predict(X_new)
